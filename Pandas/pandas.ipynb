# %%
import pandas as pd 
import numpy as np

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
print(pd.show_versions)
# Out:
# <function show_versions at 0x000001CE7FEFC040>

# %%
a=[3,6,8,1]
var=pd.Series(a)
print(var)
# Out:
# 0    3
# 1    6
# 2    8
# 3    1
# dtype: int64

# %%
var1=pd.Series(data=a,index=["x","h","m","w"])
print(var1)
# Out:
# x    3
# h    6
# m    8
# w    1
# dtype: int64

# %%
s1=pd.Series(data=[1,2,3,4,5],index=list('abcde'))
s2=pd.Series(data=[10,20,30,40,50],index=list('abcde'))
df=pd.DataFrame({'A':s1,'B':s2})
print(df)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
# d  4  40
# e  5  50

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
data = {
  "calories": [420, 380, 39400,456,7890],
  "duration": [50, 40, 45,23,54]
}

myvar = pd.DataFrame(data,index=list(range(1,6)))

print(myvar)
myvar.rename(columns={'calories':'CALORIES'},inplace=True)
print(myvar)
# Out:
#    calories  duration
# 1       420        50
# 2       380        40
# 3     39400        45
# 4       456        23
# 5      7890        54
#    CALORIES  duration
# 1       420        50
# 2       380        40
# 3     39400        45
# 4       456        23
# 5      7890        54

# %%
s3=pd.DataFrame(data=np.random.randint(1,10),index=list('abcde'),columns=list('stuvwxyz'))
print(s3)
# Out:
#    s  t  u  v  w  x  y  z
# a  8  8  8  8  8  8  8  8
# b  8  8  8  8  8  8  8  8
# c  8  8  8  8  8  8  8  8
# d  8  8  8  8  8  8  8  8
# e  8  8  8  8  8  8  8  8

# %%
print(myvar.loc[[0, 3]])
# Out:
#    calories  duration
# 0       420        50
# 3       456        23

# %%
print(myvar.loc[2])
print(myvar.loc[0:3])
# Out:
# calories    39400
# duration       45
# Name: 2, dtype: int64
#    calories  duration
# 0       420        50
# 1       380        40
# 2     39400        45
# 3       456        23

# %%
data = {
  "calories": [420, 380, 39400,456,7890],
  "duration": [50, 40, 45,23,54]
}

df = pd.DataFrame(data,index=["data1","data2","data3","data4","data5"])

print(df)
# Out:
#        calories  duration
# data1       420        50
# data2       380        40
# data3     39400        45
# data4       456        23
# data5      7890        54

# %%
print(df.loc["data2":"data4"])
# Out:
#        calories  duration
# data2       380        40
# data3     39400        45
# data4       456        23

# %%
print(df.loc[["data2","data4"]])
# Out:
#        calories  duration
# data2       380        40
# data4       456        23

# %%
ds = pd.read_csv('50_Startups_test.csv')
print(ds)
# Out:
#      R&D Spend  Administration  Marketing Spend       State
# 0     61749.16       118175.79        294919.57     Florida
# 1     86619.70      1535814.10        118148.20    New York
# 2     76263.86      1183867.00        298664.47  California
# 3     68389.47      1583773.40        299737.29    New York
# 4     73964.56      1282782.70        303319.26     Florida
# 5     66532.53       105751.03        304768.73         NaN
# 6     77644.01        99881.34        140574.81    New York
# 7     64664.71      1839553.10        137962.62  California
# 8    756328.80       184135.98        134050.07     Florida
# 9    163334.88       188679.17        304981.62  California
# 10  1601913.00       110584.11        229160.95     Florida
# 11   106671.96        91890.61        249744.55  California
# 12    93663.75       128320.38        249839.44     Florida
# 13    96992.39       138495.07        252664.93  California
# 14   116943.24       158547.42        256512.92     Florida
# ...

# %%
ds.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0   61749.16       118175.79        294919.57     Florida
# 1   86619.70      1535814.10        118148.20    New York
# 2   76263.86      1183867.00        298664.47  California
# 3   68389.47      1583773.40        299737.29    New York
# 4   73964.56      1282782.70        303319.26     Florida
# 5   66532.53       105751.03        304768.73         NaN
# 6   77644.01        99881.34        140574.81    New York
# 7   64664.71      1839553.10        137962.62  California
# 8  756328.80       184135.98        134050.07     Florida
# 9  163334.88       188679.17        304981.62  California

# %%
ds.to_string()
# Out:
# '     R&D Spend  Administration  Marketing Spend       State\n0     61749.16       118175.79        294919.57     Florida\n1     86619.70      1535814.10        118148.20    New York\n2     76263.86      1183867.00        298664.47  California\n3     68389.47      1583773.40        299737.29    New York\n4     73964.56      1282782.70        303319.26     Florida\n5     66532.53       105751.03        304768.73         NaN\n6     77644.01        99881.34        140574.81    New York\n7     64664.71      1839553.10        137962.62  California\n8    756328.80       184135.98        134050.07     Florida\n9    163334.88       188679.17        304981.62  California\n10  1601913.00       110584.11        229160.95     Florida\n11   106671.96        91890.61        249744.55  California\n12    93663.75       128320.38        249839.44     Florida\n13    96992.39       138495.07        252664.93  California\n14   116943.24       158547.42        256512.92     Florida\n15   116523.61       
# ...

# %%
ds.tail(12)
# Out:
#      R&D Spend  Administration  Marketing Spend       State
# 17    94657.16      1485077.50        282574.31  California
# 18    76107.60       127884.55        353183.81  California
# 19    66051.52      1828645.50        118148.20     Florida
# 20   165379.20             NaN        471784.10    New York
# 21   162547.70       158377.59        443898.53  California
# 22  1534441.51       108145.55        407934.54  California
# 23   144472.41       118871.85        383199.62    New York
# 24   142607.34        91391.77        366168.42     Florida
# 25   131676.90        99884.71        362861.36    New York
# 26   136615.46       148198.87        127716.82     Florida
# 27   130698.13       148530.06        323876.68  California
# 28   165379.20       136897.80        471784.10    New York

# %%
ds.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State'], dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        29 non-null     float64
#  1   Administration   28 non-null     float64
#  2   Marketing Spend  29 non-null     float64
#  3   State            28 non-null     object
# dtypes: float64(3), object(1)
# memory usage: 1.0+ KB

# %%
dt=pd.read_csv('dirtydata.csv')
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# dt.info()

# %% [markdown]
# df=dt.dropna()
# df

# %%
dt.dropna(inplace=True)
print(dt)
dt.loc[12,"Maxpulse"]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dt=pd.read_csv('dirtydata.csv')
dt.fillna(130,inplace=True,)
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dt=pd.read_csv('dirtydata.csv')
dt["Calories"].fillna(130,inplace=True)
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dt=pd.read_csv('dirtydata.csv')
x=dt["Calories"].mean()
dt["Calories"].fillna(x,inplace=True)
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
dt=pd.read_csv('dirtydata.csv')
x=dt["Calories"].median()
dt["Calories"].fillna(x,inplace=True)
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dt=pd.read_csv('dirtydata.csv')
x=dt["Calories"].mode()[0]
dt["Calories"].fillna(x,inplace=True)
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dt=pd.read_csv('dirtydata.csv')
dt.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
dt.drop_duplicates(inplace=True)
dt
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...
